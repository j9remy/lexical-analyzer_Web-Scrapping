# %%
import json
import pandas as pd

with open('./scrapper_soybean_twitter.json', encoding='utf-8') as fh:
    data = json.load(fh)

# %%
data
# Out:
# {'colheita soja': ['Faustão de Moraes',
#   'Abril, colheita de soja',
#   '(A Argentina teve seca)',
#   'Robin Brooks',
#   "Brazil is on track to become the Switzerland of Latin America. A huge trade surplus is emerging, unlike any other country in the region. This is going to give Brazil external stability and a strong currency unlike the rest of Latin America. Brazil will be the region's anchor...",
#   'Mostrar esta sequência',
#   'faixa gospel',
#   'almoçando com meu pai assistindo globo rural cujo tema é plantação e colheita de soja',
#   'Ary Goncalvez',
#   'Dom Pedrito RS ',
#   'Finalizando Colheita Soja 2023 ',
#   'Obrigado Deus por esse momento que o sr proporciona ',
#   'Que Venha a Próxima com sua Benção ',
#   'Obrigado ',
#   'Ismael Souza ˢᶜᶦ',
#   'Em resposta a ',
#   ' @bernapoa2',
#   'Os caras jogam num campo de colheita de soja e querem meter essa',
#   'Marcone Hilton',
# ...

# %%
from transformers import pipeline

# %%
sentiment_pipeline = pipeline("sentiment-analysis")
# data = ["I love you", "I hate you"]
sentiment_pipeline(data['semeadura soja'][1])
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sentiment_pipeline = pipeline("sentiment-analysis")
#       2 # data = ["I love you", "I hate you"]
#       3 sentiment_pipeline(data['semeadura soja'][1])
#
# File c:\Users\jerem\Downloads\scrapping-twitter\.venv\lib\site-packages\transformers\pipelines\__init__.py:788, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, use_auth_token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
# ...

# %%
data['semeadura soja'][1]
# Out:
# 'Fux pede informações à Embrapa sobre ampliação do calendário de semeadura de soja.'

# %%
sentiment_pipeline = pipeline("sentiment-analysis")
df = pd.DataFrame()
for search in data:
    for idx, line in enumerate(data[search]):
        dict_sentiment: dict = sentiment_pipeline(data[search][idx])[0]
        dict_sentiment.update({'search': search})
        # print(f'{search} ({idx}): {dict_sentiment}')
        df_dict = pd.DataFrame([dict_sentiment])
        df = pd.concat([df, df_dict], ignore_index=True)
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 sentiment_pipeline = pipeline("sentiment-analysis")
#       2 df = pd.DataFrame()
#       3 for search in data:
#
# File c:\Users\jerem\Downloads\scrapping-twitter\.venv\lib\site-packages\transformers\pipelines\__init__.py:788, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, use_auth_token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     784 # Infer the framework from the model
# ...

# %%
df
# Out:
#         label     score          search
# 0    POSITIVE  0.985582      preço soja
# 1    NEGATIVE  0.981376      preço soja
# 2    POSITIVE  0.996733      preço soja
# 3    POSITIVE  0.999470      preço soja
# 4    POSITIVE  0.981114      preço soja
# ..        ...       ...             ...
# 278  NEGATIVE  0.981376  soja no brasil
# 279  POSITIVE  0.996733  soja no brasil
# 280  POSITIVE  0.999470  soja no brasil
# 281  POSITIVE  0.999531  soja no brasil
# 282  POSITIVE  0.999531  soja no brasil
#
# [283 rows x 3 columns]

# %%
df = pd.DataFrame()
df_dict = pd.DataFrame([{'label': 'POSITIVE', 'score': 0.9967325925827026}])
df = pd.concat([df, df_dict], ignore_index=True)
df
# Out:
#       label     score
# 0  POSITIVE  0.996733
# 1  POSITIVE  0.996733
# 2  POSITIVE  0.996733
# 3  POSITIVE  0.996733
# 4  POSITIVE  0.996733
